# %% [markdown]
# # Telescopio Espacial James Webb

# %% [markdown]
# El telescopio espacial James Webb  (en inglés, James Webb Space Telescope (JWST)) es el principal observatorio de la próxima década y está al servicio de miles de astrónomos de todo el mundo. Webb estudia todas las fases de la historia de nuestro Universo, desde los primeros resplandores luminosos después del Big Bang, pasando por la evolución de nuestro propio sistema solar, hasta la formación de sistemas solares capaces de sustentar la vida en planetas como la Tierra.

# %% [markdown]
# ![](Assets/james_webb_telescope.jpg)

# %% [markdown]
# ## Una colaboración internacional

# %% [markdown]
# El telescopio espacial James Webb es una colaboración internacional entre la NASA, la ESA (Agencia Espacial Europea) y la CSA (Agencia Espacial Canadiense).
#
# El Centro de Vuelo Espacial Goddard de la NASA gestionó los trabajos para su desarrollo. El principal socio industrial es Northrop Grumman; el Instituto de Ciencias del Telescopio Espacial se ocupa del funcionamiento de Webb desde su lanzamiento. Miles de científicos, ingenieros y técnicos de 14 países, 29 estados de Estados Unidos y Washington D.C. contribuyeron al diseño, la construcción, las pruebas, la integración, el lanzamiento, la puesta en marcha y las operaciones de Webb.

# %% [markdown]
# ## Lanzamiento y duración de la misión

# %% [markdown]
# El telescopio espacial James Webb fue lanzado el 25 de diciembre de 2021. No orbita alrededor de la Tierra como el telescopio espacial Hubble, sino que orbita alrededor del Sol a 1,5 millones de kilómetros (un millón de millas) de distancia de la Tierra, en lo que se denomina el segundo punto de Lagrange o L2.
# El tiempo nominal de la misión es de cinco años, con un límite en principio de diez años. JWST necesita usar propelente para mantener su órbita de halo alrededor del punto de Lagrange L2, lo que proporciona un límite superior a su vida útil esperada, y fue diseñado para transportar suficiente propelente para diez años.La misión científica programada de cinco años comienza después de una fase de prueba y puesta en marcha de 6 meses.La órbita L2 es solo metaestable, por lo que requiere un mantenimiento de estación orbital o el objeto se alejará de esta configuración orbital.

# %% [markdown]
# ![](Assets/50732853538_7ff9098b27_c.jpg)

# %% [markdown]
# ## Astronomía infrarroja

# %% [markdown]
# La sensibilidad infrarroja sin precedentes de Webb está ayudando a los astrónomos a comparar las galaxias más tenues y antiguas con las grandes galaxias espirales y elípticas actuales, lo que nos ayuda a comprender cómo se forman las galaxias durante el transcurso de miles de millones de años.

# %% [markdown]
# ![](Assets/52259221868_b757d6cdea_k.jpg)

# %% [markdown]
# ### Links

# %% [markdown]
# - https://science.nasa.gov/mission/webb/
# - https://es.wikipedia.org/wiki/Telescopio_espacial_James_Webb
# - https://science.nasa.gov/mission/webb/multimedia/images/
